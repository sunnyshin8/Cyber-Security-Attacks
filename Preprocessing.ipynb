# %%
# Importing libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# loading the dataset
df = pd.read_csv('data/cybersecurity_attacks.csv')

# %%
# checking the shape of the dataset
print(df.shape)
# Out:
# (40000, 25)

# %%
df.head()
# Out:
#              Timestamp Source IP Address Destination IP Address  Source Port  \
# 0  2023-05-30 06:33:58     103.216.15.12           84.9.164.252        31225
# 1  2020-08-26 07:08:30    78.199.217.198         66.191.137.154        17245
# 2  2022-11-13 08:23:25      63.79.210.48          198.219.82.17        16811
# 3  2023-07-02 10:38:46     163.42.196.10        101.228.192.255        20018
# 4  2023-07-16 13:11:07     71.166.185.76        189.243.174.238         6131
#
#    Destination Port Protocol  Packet Length Packet Type Traffic Type  \
# 0             17616     ICMP            503        Data         HTTP
# 1             48166     ICMP           1174        Data         HTTP
# 2             53600      UDP            306     Control         HTTP
# 3             32534      UDP            385        Data         HTTP
# 4             26646      TCP           1462        Data          DNS
#
#                                         Payload Data  ... Action Taken  \
# ...

# %%
# Finding the missing values
df.isnull().sum()
# Out:
# Timestamp                     0
# Source IP Address             0
# Destination IP Address        0
# Source Port                   0
# Destination Port              0
# Protocol                      0
# Packet Length                 0
# Packet Type                   0
# Traffic Type                  0
# Payload Data                  0
# Malware Indicators        20000
# Anomaly Scores                0
# Alerts/Warnings           20067
# Attack Type                   0
# Attack Signature              0
# Action Taken                  0
# Severity Level                0
# User Information              0
# Device Information            0
# Network Segment               0
# Geo-location Data             0
# Proxy Information         19851
# Firewall Logs             19961
# IDS/IPS Alerts            20050
# Log Source                    0
# dtype: int64

# %%
# Replacing the missing values with 'None'
df['Malware Indicators'].fillna('None', inplace=True)
df['Alerts/Warnings'].fillna('None', inplace=True)
df['Firewall Logs'].fillna('None', inplace=True)
df['IDS/IPS Alerts'].fillna('None', inplace=True)

# Replacing the missing values with 'No Proxy'
df['Proxy Information'].fillna('No Proxy', inplace=True)

# %%
df.isnull().sum()
# Out:
# Timestamp                 0
# Source IP Address         0
# Destination IP Address    0
# Source Port               0
# Destination Port          0
# Protocol                  0
# Packet Length             0
# Packet Type               0
# Traffic Type              0
# Payload Data              0
# Malware Indicators        0
# Anomaly Scores            0
# Alerts/Warnings           0
# Attack Type               0
# Attack Signature          0
# Action Taken              0
# Severity Level            0
# User Information          0
# Device Information        0
# Network Segment           0
# Geo-location Data         0
# Proxy Information         0
# Firewall Logs             0
# IDS/IPS Alerts            0
# Log Source                0
# dtype: int64

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# %%
# Using Timestamp to create new features
df['Year'] = df['Timestamp'].dt.year
df['Month'] = df['Timestamp'].dt.month_name()
df['Date'] = df['Timestamp'].dt.day
df['Hour'] = df['Timestamp'].dt.hour
df['Day'] = df['Timestamp'].dt.day_name()

# %%
df.head()
# Out:
#             Timestamp Source IP Address Destination IP Address  Source Port  \
# 0 2023-05-30 06:33:58     103.216.15.12           84.9.164.252        31225
# 1 2020-08-26 07:08:30    78.199.217.198         66.191.137.154        17245
# 2 2022-11-13 08:23:25      63.79.210.48          198.219.82.17        16811
# 3 2023-07-02 10:38:46     163.42.196.10        101.228.192.255        20018
# 4 2023-07-16 13:11:07     71.166.185.76        189.243.174.238         6131
#
#    Destination Port Protocol  Packet Length Packet Type Traffic Type  \
# 0             17616     ICMP            503        Data         HTTP
# 1             48166     ICMP           1174        Data         HTTP
# 2             53600      UDP            306     Control         HTTP
# 3             32534      UDP            385        Data         HTTP
# 4             26646      TCP           1462        Data          DNS
#
#                                         Payload Data  ...   Geo-location Data  \
# ...

# %%
df.to_csv('data/cybersecurity_attacks_cleaned.csv', index=False)

# %%
#proportion of attacks by year
attack_by_year = df['Year'].value_counts(normalize=True)*100
attack_by_year
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #proportion of attacks by year
# ----> 2 attack_by_year = df['Year'].value_counts(normalize=True)*100
#       3 attack_by_year
#
# NameError: name 'df' is not defined
